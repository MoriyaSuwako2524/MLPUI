# %%
import torch

# %%
# !pip uninstall torch torchvision
# Out:
# ^C

# %%
import sys
# !{sys.executable} -m pip install torch torchvision
# Out:
# ^C
#   WARNING: The script isympy.exe is installed in 'C:\Users\suwak\AppData\Local\Programs\Python\Python313\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The scripts torchfrtrace.exe and torchrun.exe are installed in 'C:\Users\suwak\AppData\Local\Programs\Python\Python313\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#
# [notice] A new release of pip is available: 25.2 -> 26.0.1
# [notice] To update, run: C:\Users\suwak\AppData\Local\Programs\Python\Python313\python.exe -m pip install --upgrade pip
# ...
#   Using cached sympy-1.14.0-py3-none-any.whl.metadata (12 kB)
# ...
#   Using cached mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# ...
#    ---------------------------------------- 0.0/113.8 MB ? eta -:--:--
# ...
